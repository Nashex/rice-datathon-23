# %%
from __future__ import unicode_literals, print_function
import pickle
import plac
import random
from pathlib import Path

import pkg_resources
pkg_resources.require("spacy==2.3.5")
import spacy
from spacy.util import minibatch, compounding


n_iter = 20
LABEL = ["vendor", "totalAmount", "totalLabel", "address", "date"]

with open ('Data/spacy.txt', 'rb') as fp:
    TRAIN_DATA = pickle.load(fp)
    
nlp = spacy.blank('en')
ner = nlp.create_pipe('ner')
nlp.add_pipe(ner)

for i in LABEL:
    ner.add_label(i)
    

optimizer = nlp.begin_training()

for itn in range(n_iter):
    random.shuffle(TRAIN_DATA)
    losses = {}
    batches = minibatch(TRAIN_DATA, size=compounding(4., 32., 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        nlp.update(texts, annotations, sgd=optimizer, drop=0.1,
                   losses=losses)
    print('Losses', losses)
# Out:
# Losses {'ner': 16978.71791008512}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-780ec8276222> in <module>
#      33     for batch in batches:
#      34         texts, annotations = zip(*batch)
# ---> 35         nlp.update(texts, annotations, sgd=optimizer, drop=0.1,
#      36                    losses=losses)
#      37     print('Losses', losses)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spacy/language.py in update(self, docs, golds, drop, sgd, losses, component_cfg)
#     527             kwargs = component_cfg.get(name, {})
#     528             kwargs.setdefault("drop", drop)
# --> 529             proc.update(docs, golds, sgd=get_grads, losses=losses, **kwargs)
#     530             for key, (W, dW) in grads.items():
#     531                 sgd(W, dW, key=key)
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update.finish_parser_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.make_updates()
#
# _parser_model.pyx in spacy.syntax._parser_model.precompute_hiddens.begin_update.backward()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spacy/_ml.py in backward(dY_ids, sgd)
#     195             Wopfi = self.ops.xp.ascontiguousarray(Wopfi)
#     196             Wopfi = Wopfi.reshape((self.nO * self.nP, self.nF * self.nI))
# --> 197             dXf = self.ops.gemm(dY.reshape((dY.shape[0], self.nO * self.nP)), Wopfi)
#     198
#     199             # Reuse the buffer
#
# KeyboardInterrupt:

# %%
test_text = """
0,0,"DE LUXE CIRCLE FRESH MART SDN BHD (MUTIARA RINI 16) GST NO:001507647488 CO REG NO:797887-W NO, 89&91, JALAN UTAMA, TAMAN MUTIA RINI, 81300 SKUDAI, JOHOR. TEL:016-7780546 MT161201805120055 12/05/18 12:12:57 PM CHU PECK CASHIER: 12/05/18 12:13:17 PM HEAVEN & EARTH AYATAKA GREEN TEA 1.5L 8888002119454 5.00*1 5.00 S KONNYAKU 10G 7.00 S 8888338001119 3.50*2 12.00 2 TOTAL WITH GST @ 6% ITEM: 3 ROUNDING 0.00 QTY: TOTAL SAVING: 0.00 12.00 TOTAL TENDER CASH 50.00 38.00 CHANGE TAX AMOUNT GOODS GST ANALYSIS S = 6% 11.32 0.68 Z = 0% 0.00 0.00 POINTS EARNED: 11 MEMBER 0000036581 MEMBER: WONG SHOO YUEN *THANK YOU. SEE YOU AGAIN !! *CUSTOMER CARE LINE : 012-7092889 *CUSTOMERSERVICE@DELUXEGROUPS.COM"
0,00d0608566104,"SANYU STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM MOBILE /WHATSAPPS : +6012-918 7937 TEL: +603-3362 4137 GST ID NO: 001531760640 TAX INVOICE OWNED BY : SANYU SUPPLY SDN BHD (1135772-K) CASH SALES COUNTER 1. 2012-0029 RESTAURANT ORDER CHIT NCR 3.5""X6"" 3 X 2.9000 8.70 SR TOTAL SALES INCLUSIVE GST @6% 8.70 DISCOUNT 0.00 TOTAL 8.70 ROUND ADJ 0.00 FINAL TOTAL 8.70 CASH 10.00 CHANGE 1.30 AMOUNT(RM) GST SUMMARY TAX(RM) SR @ 6% 8.21 0.49 INV NO: CS-SA-0079030 DATE: 18/04/2017 GOODS SOLD ARE NOT RETURNABLE & REFUNDABLE THANK YOU FOR YOUR PATRONAGE PLEASE COME AGAIN. TERIMA KASIH SILA DATANG LAGI ** PLEASE KEEP THIS RECEIPT FOR PROVE OF PURCHASE DATE FOR I.T PRODUCT WARRANTY PURPOSE ** FOLLOW US IN FACEBOOK : SANYU.STATIONERY"
"""
doc = nlp(test_text)
for ent in doc.ents:
    print(ent.label_, ":", ent.text)
# Out:
# vendor : MART SDN BHD
# totalAmount : 7780546
# date : 12/05/18
# address : NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalAmount : 8.70
# totalLabel : FINAL TOTAL
# totalAmount : 8.70
# date : 18/04/2017

# %%
import pandas as pd

test = pd.read_csv("ocr_test.csv")
for i, row in test.iterrows():
    print("\nDoc", i)
    content = row[2]
    doc = nlp(content)
    for ent in doc.ents:
        print(ent.label_, ":", ent.text)
# Out:
# Doc 0
# vendor : MR D.T.Y. (JOHOR) SDN BHD
# address : LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR
# totalLabel : TOTAL ROUNDED
# totalAmount : 33.90
#
# Doc 1
# vendor : MENARA DION #02-03, LEVEL 2, 27, JALAN SULTAN ISMAIL, 50250 KUALA LUMPUR.
# date : 25/06/18
# date : 25/06/18
#
# Doc 2
# vendor : GERBANG ALAF RESTAURANTS SDN BHD
# vendor : LICENSEE OF MCDONALD'S
# address : LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39,47400 PETA ING JAYA SELANGOR
# vendor : MCDONALD'S PERMAS JAYA
# date : 25/05/2018
# totalAmount : 11.10
# totalLabel : TOTAL ROUNDED
# totalAmount : 21.10
#
# Doc 3
# vendor : AEON CO.
# address : 3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR
# totalAmount : 122.80
# totalLabel : TOTAL AFTER ADJ INCL GST
#
# Doc 4
# vendor : 99 SPEED MART S/B
# address : LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR
# date : 20-02-18
# totalLabel : TOTAL SALES (INCLUSIVE GST)
#
# Doc 5
# vendor : GARDENIA BAKERIES (KL) SDN BHD
# address : LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.
# date : 23/10/2017
# totalAmount : 39.87
# totalLabel : TOTAL PAYABLE
#
# Doc 6
# address : 1, JALAN DESA TEBRAU, TAMAN DESA TEBRAU, 81100 JOHOR BAHRU, JOHOR.
# date : 17/04/2018
# totalLabel : TOTAL
# totalAmount : 81.80
#
# Doc 7
# vendor : 99 SPEED MART S/B
# address : LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR
# date : 21-11-16
# totalLabel : TOTAL SALES (INCLUSIVE GST)
#
# Doc 8
# vendor : DOMINO'S PIZZA
# vendor : DOMINO'S PIZZA TAMAN UNIVERSITI
# address : 30, JLN KEBUDAYAAN 7, TMN UNIVERSITI 81300 SKUDAI, JOHOR PAY
# date : 28/04/18
# totalAmount : 39.60
# totalLabel : GRAND TOTAL
# totalAmount : 40.00
#
# Doc 9
# address : NO.17,JALAN PERMAS 1/7, BANDAR BARU PERMAS JAYA, 81750, MASAI
#
# Doc 10
# vendor : DOMINO'S PIZZA
# vendor : DOMINO'S PIZZA SEGAMBUT D-08
# date : 26/03/18
# totalAmount : 33.00
# totalLabel : GRAND TOTAL
#
# Doc 11
# vendor : PERNIAGAAN GIN KEE (81109-A)
# address : NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR
# totalLabel : TOTAL SALES (INCLUSIVE OF GST)
# totalAmount : 465.34
#
# Doc 12
# address : NO.1, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU, JOHOR,
# date : 09/06/2018
# totalLabel : GRAND TOTAL
# totalAmount : 09/06/2018
#
# Doc 13
# vendor : . D.I.Y. SDN BHD
# address : LOT 1851-A & 1851-B, JALAN KPB 6, KWANSAN PERINDUSTRIAN BLANKONG, 43300 SERI KEMBANGAN, SELANGOR
# totalLabel : TOTAL INCL. GST@6%
# totalAmount : 10.00
# date : 28-12-17
#
# Doc 14
# date : 18
#
# Doc 15
# address : LOT 37636 , JALAN 6/37A , TAMAN BUKIT MALURI , 52100 KUALA LUMPUR
#
# Doc 16
# vendor : . D.I.Y. (M) SDN BHD
# address : LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR
# totalLabel : TOTAL INCL. GST@6%
# totalAmount : 5.00
# date : 30-04-18
#
# Doc 17
# vendor : STATIONERY & BOOKS
# address : NO. 53, JALAN BESAR, 45600 BATANG BERJUNTAI SELANGOR DARUL EHSAN
# date : 23/01/2018
# totalAmount : 18.00
# totalLabel : TOTAL
#
# Doc 18
# address : LOT 2685 JLN GENTING KLANG SITE 1066 53300 KL
# totalLabel : TOTAL GROSS SHELL LOYALTY CARD 6018840126306675
#
# Doc 19
# address : NO.12,JALAN SS4C/5,PETALING JAYA SELANGOR DARUL EHSAN
# date : 10/02/2017
# totalLabel : NET TOTAL
# totalAmount : 7.40
#
# Doc 20
# vendor : ONE ONE THREE SEAFOOD RESTAURANT SDN BHD
# address : NO.1, TAMAN SRI DENGKIL, JALAN AIR HITAM 43800 DENGKIL, SELANGOR.
# date : 23-06-2018
# totalAmount : 179.50
# date : 23-06-2018
#
# Doc 21
# vendor : PERNIAGAAN GIN KEE (81109-A)
# address : NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR
# date : 02/01/2018
# totalLabel : TOTAL SALES (INCLUSIVE OF GST)
# totalAmount : 2.12
#
# Doc 22
# address : LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR.
# date : 17/04/2018
# totalAmount : 190.80
# totalLabel : TOTAL SALES (INCLUSIVE OF GST)
# totalAmount : 190.80
#
# Doc 23
# address : NO 37, JALAN MANIS 7, TAMAN SEGAR, 56100 CHERAS, KUALA LUMPUR.
# date : 08/02/2017
# totalAmount : 277.90
# totalLabel : TOTAL INCLUSIVE GST
# totalAmount : 277.00
#
# Doc 24
# vendor : AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD
# address : NO. 17-G, JALAN SETIA INDAH
# address : U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,
# date : 12/09/2017
#
# Doc 25
# vendor : PERNIAGAAN GIN KEE (81109-A)
# address : NO 290, JALAN AIR PANAS, STAPAK, 53200, KUALA LUMPUR,
# date : 12/01/2018
# totalLabel : TOTAL SALES (INCLUSIVE OF GST)
# totalAmount : 7.95
#
# Doc 26
# address : , A-G-06, DATARAN GLOMAC, JALAN SS6/5A, PUSAT BANDAR KELANA JAYA, 47301 PETALING JAYA, SELANGOR, MALAYSIA
# date : 27/02/2018
#
# Doc 27
# address : NO1.JALAN PJU 9/1,D'SARA AVEVUE BANDAR SRI D'SARA, 52000
# date : 30/03/2018
#
# Doc 28
# vendor : 99 SPEED MART S/B
# address : LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR
# date : 03-05-18
# totalLabel : TOTAL SALES (INCLUSIVE GST) RM
# totalAmount : 19.90
#
# Doc 29
# vendor : 99 SPEED MART S/B
# address : LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1243-JLN PUDU ULU
# date : 14-08-17
# totalLabel : TOTAL SALES (INCLUSIVE GST)
# totalAmount : 14.38
#
# Doc 30
# address : NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR
# date : 23-06-2018
# totalLabel : TOTAL
# totalAmount : 4.60
#
# Doc 31
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalLabel : TOTAL SALES INCLUSIVE GST @6%
# totalAmount : 2.00
# date : 07/11/2017
#
# Doc 32
# vendor : 99 SPEED MART S/B
# address : LOT P. T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1362-JLN
# date : 17-02-18
# totalLabel : TOTAL SALES (INCLUSIVE GST)
# totalAmount : 108.50
#
# Doc 33
# address : NO.17,18 & 41,JALAN BESAR, 39100 BRINCHANG, CAMERON HIGHLANDS, PAHANG
# date : 06/02/2018
# totalAmount : 109.70
# totalLabel : ROUNDED TOTAL
#
# Doc 34
# vendor : STATIONERY & BOOKS
# address : NO. 53, JALAN BESAR, 45600 BATANG BERJUNTAI SELANGOR DARUL EHSAN
# date : 15/01/2018
# totalLabel : TOTAL
# totalAmount : 55.10
#
# Doc 35
# address : LOT PTD 182908 & PTD 143216, JALAN DANGA, TAMAN NUSA BESTARI, 81300
# date : 14/04/2018
# totalLabel : TOTAL AMOUNT
# totalAmount : 21.80
# totalLabel : TOTAL AMOUNT
#
# Doc 36
# address : LOT 1851-A & 1851-B, JALAN KPB 6 , KAWASAN PERINDUSTRIAN BALAKONG , 43300 SERI KEMBANGAN , SELANGOR
# totalAmount : 11
# totalLabel : TOTAL INCL. GST@6%
# date : 16-03-18
#
# Doc 37
# vendor : LIAN HING STATIONERY SDN BHD
#
# Doc 38
# vendor : GARDENIA BAKERIES (KL) SDN BHD
# address : LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.
# date : 29/10/2017
# totalAmount : 58.86
# totalLabel : TOTAL PAYABLE
#
# Doc 39
# vendor : HANDICRAFT & TAII ORING 19, JALAN KANCIL, OFF JALAN PUDU, 55100 KUALA LUMPUR MALAYSIA
# date : 27/03/2018
# totalLabel : TOTAL INCL. OF GST
# totalAmount : 130.00
#
# Doc 40
# address : 69 JALAN NOVA U5/N, SEKSYEN U5 SUBANG BE
# totalLabel : TOTAL
# totalAmount : 12.15
#
# Doc 41
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalLabel : FINAL TOTAL
# totalAmount : 12.40
# date : 18/09/2017
#
# Doc 42
# address : NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA
# date : 05/03/18
# totalLabel : TOTAL RM INCL. OF GST
# totalAmount : 9.90
#
# Doc 43
# address : NO. 9-G, JALAN PERUBATAN 2, PANDAN INDAH, 55100 KUALA LUMPUR.
# date : 09-04-2018
# totalLabel : TOTAL
# totalAmount : 31.00
#
# Doc 44
# vendor : UNIHAKKA INTERNATIONAL SDN BHD
# date : 14 MAY 2018
# address : 12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR
# totalLabel : TOTAL AMOUNT
# totalAmount : 8.90
#
# Doc 45
# address : 2ND FLOOR, 1 UTAMA SHOPPING CENTRE, NO1, LEBUH BANDAR UTAMA,47800 P.JAYA
# totalLabel : TOTAL AMOUNT(INCL. GST) -0.02
# totalAmount : 31.45
#
# Doc 46
# vendor : GARDENIA BAKERIES (KL) SDN BHD
# address : LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.
# date : 10/10/2017
# totalAmount : 27.20
# totalLabel : TOTAL PAYABLE
#
# Doc 47
# address : NO: 28, JALAN ASTANA 1C, BANDAR BUKIT RAJA, 41050 KLANG SELANGOR D. E, MALAYSIA
# date : 20/11/2017
# totalAmount : 39.80
#
# Doc 48
# vendor : AEON CO.
# address : 3 FLOOR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR
# totalAmount : 5.90
# totalLabel : TOTAL AFTER ADJ INCL GST
# totalAmount : 5.90
# totalAmount : 5.57
# totalLabel : TOTAL
# totalAmount : 5.57
#
# Doc 49
# vendor : PERNIAGAAN GIN KEE (81109-A)
# address : NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR
# date : 11/01/2018
# totalLabel : TOTAL SALES (INCLUSIVE OF GST)
#
# Doc 50
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalAmount : 8.70
# date : 20/10/2017
#
# Doc 51
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalLabel : FINAL TOTAL
# totalAmount : 9.30
# date : 26/11/2017
#
# Doc 52
# address : LOT 1-0-2, JLN 1/50, DIAMOND SQUARE, OFF JLN GOMBAK 53000 KUALA LUMPUR
# date : 14/03/2018
#
# Doc 53
# address : NAHKOTA CHERAS MIZU MENTAI SDN. BHD.
# date : 31-03-2018
# totalLabel : TOTAL
# totalAmount : 65.55
# date : 31-03-2018
#
# Doc 54
# vendor : YEE S.H.H. MOTOR (SUNGAI RENGIT) SDN. BHD.
# address : NO. 343, JALAN KURAU, SUNGAI RENGIT, 81620 PENGERANG, JOHOR.
# totalLabel : GRAND TOTAL
# date : 23-01-2019
#
# Doc 55
# address : LEVEL G2, BLOCK D1. SOLARIS DUTAMAS. NO. 1, JALAN DUTAMAS 1, 50480 KUALA LUMPUR.
# date : 14/01/2018
#
# Doc 56
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalLabel : TOTAL SALES INCLUSIVE GST @6%
# totalAmount : 4.50
# totalLabel : FINAL TOTAL
# totalAmount : 4.50
# date : 06/07/2017
#
# Doc 57
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalAmount : 3.90
# totalAmount : 3.90
#
# Doc 58
# address : NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR
# date : 26-06-2018
# totalLabel : TOTAL
# totalAmount : 4.60
#
# Doc 59
# address : NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR
# date : 05-03-2018
# totalLabel : TOTAL (INCLUSIVE OF GST)
# totalAmount : 6.00
#
# Doc 60
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalAmount : 46.90
# totalAmount : 46.90
#
# Doc 61
# address : NO.2, GROUND FLOOR, JALAN REKO SENTRAL 8 TAMAN REKO SENTRAL, 43000 KAJANG SELANGOR
# date : 19/03/2018
# totalAmount : 19/03/2018
#
# Doc 62
# vendor : . D.I.Y. SDN BHD
# address : LOT 1851-A & 1851-B, JALAN KPB 6, KWANSAN PERINDUSTRIAN BLANKONG, 43300 SERI KEMBANGAN, SELANGOR
# totalLabel : TOTAL INCL. GST@6%
# totalAmount : 5.57
# date : 18-10-17
#
# Doc 63
# vendor : GARDENIA BAKERIES (KL) SDN BHD
# address : LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.
# date : 17/08/2017
# totalAmount : 7.97
# totalLabel : TOTAL PAYABLE
#
# Doc 64
# address : 12, JALAN BUNGA TANJUNG, 2/16 SEKSYEN 2, 40000 SHAH ALAM, SELANGOR
# totalLabel : TOTAL AMT INCL. GST @ 6%
# totalAmount : 31.80
# totalLabel : TOTAL AMT PAYABLE
# date : 19/03/2018
#
# Doc 65
# address : NO. 47, JALAN MERANTI 1A, BANDAR BARU UTAMA, 44300 BATANG KALI, SELANGOR.
# date : 20/05/2018
# totalLabel : TOTAL SALES (INCLUSIVE OF GST)
#
# Doc 66
# address : NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR
# date : 09-04-2018
# totalAmount : 8.60
# totalLabel : TOTAL
#
# Doc 67
# vendor : UNIHAKKA INTERNATIONAL SDN BHD
# date : 27 MAY 2018
# address : 12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR
# totalLabel : TOTAL AMOUNT
# totalAmount : 10.70
# totalAmount : 10.70
#
# Doc 68
# vendor : GARDENIA BAKERIES (KL) SDN BHD
# address : LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.
# date : 14/10/2017
# totalAmount : 33.80
# totalLabel : TOTAL PAYABLE
#
# Doc 69
# vendor : AEON CO.
# address : 3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR
# totalAmount : 17.70
# totalLabel : TOTAL AFTER ADJ INCL GST
# totalAmount : 33.00
# date : 19/02/2018
#
# Doc 70
# address : LOT F1-01, 6, JALAN 8/27A, SEKSYEN 5 WANGSA MAJU, 53300 KUALA LUMPUR, WILAYAH PERSEKUTUAN KUALA LUMPUR, MALAYSIA.
# date : 26/02/2018
#
# Doc 71
# address : NO: 28, JALAN ASTANA 1C, BANDAR BUKIT RAJA, 41050 KLANG SELANGOR D.E, MALAYSIA
# date : 20/12/2017
#
# Doc 72
# vendor : AEON CO.
# address : 3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR
# totalAmount : 99.90
# totalLabel : TOTAL AFTER ADJ INCL GST
# totalAmount : 99.90
# date : 27/05/2018
#
# Doc 73
# address : LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR.
# date : 31/03/2018
# totalAmount : 174.90
# totalLabel : TOTAL SALES (INCLUSIVE OF GST)
#
# Doc 74
# vendor : AEON CO.
# address : 3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR
# totalAmount : 10.20
# totalLabel : TOTAL AFTER ADJ INCL GST
# totalAmount : 10.20
# date : 22/04/2018
#
# Doc 75
# vendor : . D.I.Y. (M) SDN BHD
# address : LOT 1851 -A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR
# totalAmount : 8.60
# date : 06-04-16
#
# Doc 76
# address : BHD NO.1 JALAN PJU 1A/46, OFF JALAN LAPANGAN TERBANG SUBANG PETALING JAYA SELANGOR 47301
# date : 18/06/2018
#
# Doc 77
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalLabel : FINAL TOTAL
# date : 20/09/2017
#
# Doc 78
# vendor : 99 SPEED MART S/B
# address : LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1225-DENGKIL
# date : 28-11-18
# totalLabel : TOTAL SALES (INCLUSIVE GST)
#
# Doc 79
# address : UNIT G-5B, GROUND FLOOR, WISMA UOA II, NO 21, JALAN PINANG, 50450 KUALA LUMPUR, MALAYSIA
# totalAmount : 7.42
# totalLabel : TOTAL AMT INCL GST @ 6%
# totalAmount : 7.00
#
# Doc 80
# vendor : UNIHAKKA INTERNATIONAL SDN BHD
# date : 16 APR 2018
# address : 12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR
# totalLabel : NETT TOTAL
# totalAmount : 8.20
#
# Doc 81
# vendor : GARDENIA BAKERIES (KL) SDN BHD
# address : LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.
# date : 03/09/2017
# totalAmount : 29.59
# totalLabel : TOTAL PAYABLE
#
# Doc 82
# vendor : SANG KEE CHERAS RESTAURANT
# address : 69, JALAN TEMENGGUNG 3/9 BANDAR MAHKOTA CHERAS 43200 CHERAS SELANGOR
# date : 03/05/2018
# totalLabel : TOTAL INCL GST 2.50
# totalAmount : 2.50
#
# Doc 83
# address : NO 2, JALAN BULAN BM U5/BM, SEKSYEN U5, 40150 SHAH ALAM, SELANGOR
# date : 22/01/2017
# totalAmount : 67.85
# totalLabel : NET TOTAL
# totalAmount : 100.00
#
# Doc 84
# vendor : . D.I.Y. (M) SDN BHD
# address : LOT 1851-A & 1851-B, JALAN KP8 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR
# totalLabel : TOTAL INCL. GST RM
# totalAmount : 8.11
# totalAmount : 8.10
# totalLabel : TOTAL ROUNDED
# date : 17-06-18
#
# Doc 85
# vendor : GARDENIA BAKERIES (KL) SDN BHD
# address : LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.
# date : 22/10/2017
# totalAmount : 34.21
# totalLabel : TOTAL PAYABLE
#
# Doc 86
# address : LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR.
# date : 06/03/2018
# totalAmount : 127.20
# totalLabel : TOTAL SALES (INCLUSIVE OF GST)
#
# Doc 87
# vendor : 99 SPEED MART S/B
# address : LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIM KAPAR 42100 KLANG, SELANGOR
# totalLabel : TOTAL SALES (INCLUSIVE GST)
# totalAmount : 82.80
#
# Doc 88
# vendor : & CARRY SDN BHD
# vendor : PASARAYA BORONG SUPER SEVEN
# address : NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI BULOH SEKSYEN U3 SHAH ALAM,40150
# date : 22-06-2017
# totalLabel : TOTAL
#
# Doc 89
# vendor : MASTER HARDWARE & ELECTRICAL
# address : NO.113G & 115G, JALAN SETIA GEMBILANG U13/BG BANDAR SETIA ALAM, 40170 BANDAR SETIA ALAM, SELANGOR.
# date : 22/12/2017
# totalAmount : 15.90
# totalLabel : TOTAL AMT ROUNDED
# totalAmount : 15.90
#
# Doc 90
# address : LOT B-005-006,BASEMENT LEVEL 1 THE STARLING MALL JALAN SS21/60,DAMANSARA UTAMA.
# totalAmount : 13.78
# totalLabel : TOTAL (GST INCL)
# totalAmount : 13.78
#
# Doc 91
# vendor : 99 SPEED MART S/B
# address : LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIM KAPAR 42100 KLANG, SELANGOR
# date : 30-06-16
# totalLabel : TOTAL SALES (INCLUSIVE GST)
# totalAmount : 27.28
#
# Doc 92
# address : NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA
#
# Doc 93
# vendor : . D.I.Y. (M) SDN BHD
# address : LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR
# totalAmount : 11
# totalLabel : TOTAL INCL. GST@6%
# totalAmount : 68.10
# date : 22-04-16
#
# Doc 94
# vendor : AEON CO.
# address : 3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR
# totalAmount : 98.35
# totalLabel : TOTAL AFTER ADJ INCL GST
#
# Doc 95
# vendor : 99 SPEED MART S/B
# address : LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1032-SUBANG PERDANA
# date : 21-05-17
# totalLabel : TOTAL SALES (INCLUSIVE GST)
#
# Doc 96
# address : NO 33, 35, G F,JALAN TEMENGGUNG 3/9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR
# date : 03/04/2018
#
# Doc 97
# address : NO: 28, JALAN ASTANA 1C, BANDAR BUKIT RAJA, 41050 KLANG SELANGOR D.E, MALAYSIA
# date : 20/12/2017
#
# Doc 98
# address : NO. 2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR
# date : 12-11-2017
# totalLabel : TOTAL (INCLUSIVE OF GST)
# totalAmount : 62.80
#
# Doc 99
# vendor : . D.I.Y. (M) SDN BHD
# address : LOT 1851-A & 1851-B, JALAN KPB 6 , KAWASAN PERINDUSTRIAN BALAKONG , 43300 SERI KEMBANGAN, SELANGOR
#
# Doc 100
# address : 41-1, JLN RADIN ANUM 2, SRI PETALING, 57000 KUALA LUMPUR.
# date : 27/06/2018
#
# Doc 101
# vendor : GARDENIA BAKERIES (KL) SDN BHD
# address : LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.
# date : 09/10/2017
# totalAmount : 60.24
# totalLabel : TOTAL PAYABLE
#
# Doc 102
# address : NO.59 JALAN PERMAS 9/5 BANDAR BARU PERMAS JAYA 81760 JOHOR BAHRU
# date : 15/03/2018
#
# Doc 103
# vendor : UNIHAKKA INTERNATIONAL SDN BHD
# date : 20 JUN 2018
# address : 12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR
# totalLabel : TOTAL AMOUNT
#
# Doc 104
# vendor : GARDENIA BAKERIES (KL) SDN BHD
# address : LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.
# address : GROUND FLOOR, NO. 4 & 6, JALAN SS 15/4B, 47500 SUBANG JAYA, SELANGOR
# totalAmount : 53.14
# totalLabel : TOTAL PAYABLE
#
# Doc 105
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalLabel : FINAL TOTAL
# totalAmount : 9.30
# date : 18/11/2017
#
# Doc 106
# vendor : . D.I.Y. (M) SDN BHD
# address : LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR
# totalAmount : 9.00
# totalLabel : TOTAL INCL. GST@6%
# totalAmount : 10.00
# date : 11-04-18
#
# Doc 107
# vendor : AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN BHD
# address : NO. 17-G, JALAN SETIA INDAH
# address : U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAM,
# date : 15/09/2017
#
# Doc 108
# address : NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA
# date : 12/01/18
# totalAmount : 20.98
# totalLabel : TOTAL RM INCL. OF GST 0.02 ROUNDING
#
# Doc 109
# vendor : STATIONERY SHOP NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM
# totalLabel : TOTAL SALES INCLUSIVE GST @6%
# totalAmount : 33.50
# totalLabel : FINAL TOTAL
# totalAmount : 33.50
# date : 01/11/2017
#
# Doc 110
# address : G.23 & G.22, PLAZA SERI SETIA, NO.1 JALAN SS 9/1, 47300 PJ, SELANGOR.
# totalAmount : 19.80
#
# Doc 111
# address : LOT 1626, MUKIM KAMPUNG
# date : 24-03-2018
#
# Doc 112
# vendor : STATIONERY & BOOKS
# address : NO. 53, JALAN BESAR, 45600 BATANG BERJUNTAI SELANGOR DARUL EHSAN
# date : 12/02/2018
# totalLabel : TOTAL
# totalAmount : 153.35
